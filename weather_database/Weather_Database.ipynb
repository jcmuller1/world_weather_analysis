# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import time
from datetime import datetime
import requests
import time
from scipy.stats import linregress
import gmaps

# API keys
from config import weather_api_key
from config import g_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 753

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_descrip = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_descrip,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saint-philippe
# Processing Record 2 of Set 1 | kodiak
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | cayenne
# Processing Record 5 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 1 | upernavik
# Processing Record 7 of Set 1 | khandyga
# Processing Record 8 of Set 1 | mirabad
# Processing Record 9 of Set 1 | narsaq
# Processing Record 10 of Set 1 | orvieto
# Processing Record 11 of Set 1 | dalmau
# Processing Record 12 of Set 1 | cambyreta
# City not found. Skipping...
# Processing Record 13 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 1 | jamestown
# Processing Record 15 of Set 1 | hithadhoo
# Processing Record 16 of Set 1 | barrow
# Processing Record 17 of Set 1 | tlacotepec
# Processing Record 18 of Set 1 | sisimiut
# Processing Record 19 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 1 | nuevo casas grandes
# Processing Record 21 of Set 1 | new norfolk
# Processing Record 22 of Set 1 | chapais
# Processing Record 23 of Set 1 | det udom
# Processing Record 24 of Set 1 | butaritari
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | ayagoz
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | ayan
# Processing Record 29 of Set 1 | yellowknife
# Processing Record 30 of Set 1 | najran
# Processing Record 31 of Set 1 | clyde river
# Processing Record 32 of Set 1 | kapaa
# Processing Record 33 of Set 1 | kaili
# Processing Record 34 of Set 1 | vaini
# Processing Record 35 of Set 1 | koumac
# Processing Record 36 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 1 | salalah
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | tasiilaq
# Processing Record 40 of Set 1 | siirt
# Processing Record 41 of Set 1 | dikson
# Processing Record 42 of Set 1 | fare
# Processing Record 43 of Set 1 | buta
# Processing Record 44 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 45 of Set 1 | lasa
# Processing Record 46 of Set 1 | carnarvon
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | luderitz
# Processing Record 49 of Set 1 | lompoc
# Processing Record 50 of Set 1 | severo-kurilsk
# Processing Record 1 of Set 2 | miyako
# Processing Record 2 of Set 2 | kihei
# Processing Record 3 of Set 2 | la ronge
# Processing Record 4 of Set 2 | thompson
# Processing Record 5 of Set 2 | ponta delgada
# Processing Record 6 of Set 2 | finnsnes
# Processing Record 7 of Set 2 | padang
# Processing Record 8 of Set 2 | georgetown
# Processing Record 9 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 2 | progreso
# Processing Record 11 of Set 2 | atuona
# Processing Record 12 of Set 2 | atbasar
# Processing Record 13 of Set 2 | albany
# Processing Record 14 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 2 | madison
# Processing Record 16 of Set 2 | nanortalik
# Processing Record 17 of Set 2 | hermanus
# Processing Record 18 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 2 | tazmalt
# Processing Record 20 of Set 2 | bambous virieux
# Processing Record 21 of Set 2 | puerto ayora
# Processing Record 22 of Set 2 | benton harbor
# Processing Record 23 of Set 2 | berezanka
# Processing Record 24 of Set 2 | kharan
# Processing Record 25 of Set 2 | cape town
# Processing Record 26 of Set 2 | esperance
# Processing Record 27 of Set 2 | tianpeng
# Processing Record 28 of Set 2 | bluff
# Processing Record 29 of Set 2 | saskylakh
# Processing Record 30 of Set 2 | sulangan
# Processing Record 31 of Set 2 | lagoa
# Processing Record 32 of Set 2 | mahebourg
# Processing Record 33 of Set 2 | tocopilla
# Processing Record 34 of Set 2 | arraial do cabo
# Processing Record 35 of Set 2 | souillac
# Processing Record 36 of Set 2 | batagay-alyta
# Processing Record 37 of Set 2 | hilo
# Processing Record 38 of Set 2 | marzuq
# Processing Record 39 of Set 2 | cidreira
# Processing Record 40 of Set 2 | pangkalanbuun
# Processing Record 41 of Set 2 | worland
# Processing Record 42 of Set 2 | airai
# Processing Record 43 of Set 2 | meulaboh
# Processing Record 44 of Set 2 | avarua
# Processing Record 45 of Set 2 | menongue
# Processing Record 46 of Set 2 | sitka
# Processing Record 47 of Set 2 | jalu
# Processing Record 48 of Set 2 | mar del plata
# Processing Record 49 of Set 2 | castro
# Processing Record 50 of Set 2 | bengkulu
# Processing Record 1 of Set 3 | effingham
# Processing Record 2 of Set 3 | namibe
# Processing Record 3 of Set 3 | tazovskiy
# Processing Record 4 of Set 3 | qaqortoq
# Processing Record 5 of Set 3 | alofi
# Processing Record 6 of Set 3 | urumqi
# Processing Record 7 of Set 3 | mabaruma
# Processing Record 8 of Set 3 | pevek
# Processing Record 9 of Set 3 | torbay
# Processing Record 10 of Set 3 | sampit
# Processing Record 11 of Set 3 | boca do acre
# Processing Record 12 of Set 3 | kaitangata
# Processing Record 13 of Set 3 | port alfred
# Processing Record 14 of Set 3 | qaanaaq
# Processing Record 15 of Set 3 | noumea
# Processing Record 16 of Set 3 | sanming
# Processing Record 17 of Set 3 | bull savanna
# Processing Record 18 of Set 3 | isangel
# Processing Record 19 of Set 3 | hay river
# Processing Record 20 of Set 3 | weifang
# Processing Record 21 of Set 3 | novyy urengoy
# Processing Record 22 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 3 | ulaanbaatar
# Processing Record 24 of Set 3 | ribeira grande
# Processing Record 25 of Set 3 | port elizabeth
# Processing Record 26 of Set 3 | tawau
# Processing Record 27 of Set 3 | victoria
# Processing Record 28 of Set 3 | bonavista
# Processing Record 29 of Set 3 | muisne
# Processing Record 30 of Set 3 | tawkar
# City not found. Skipping...
# Processing Record 31 of Set 3 | mezen
# Processing Record 32 of Set 3 | appenzell
# Processing Record 33 of Set 3 | sao joao da barra
# Processing Record 34 of Set 3 | bredasdorp
# Processing Record 35 of Set 3 | coquimbo
# Processing Record 36 of Set 3 | roma
# Processing Record 37 of Set 3 | cherskiy
# Processing Record 38 of Set 3 | chokurdakh
# Processing Record 39 of Set 3 | saint anthony
# Processing Record 40 of Set 3 | ostrovnoy
# Processing Record 41 of Set 3 | estelle
# Processing Record 42 of Set 3 | san jose
# Processing Record 43 of Set 3 | galveston
# Processing Record 44 of Set 3 | longyearbyen
# Processing Record 45 of Set 3 | nichinan
# Processing Record 46 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 47 of Set 3 | provideniya
# Processing Record 48 of Set 3 | dunedin
# Processing Record 49 of Set 3 | umm kaddadah
# Processing Record 50 of Set 3 | siutu
# City not found. Skipping...
# Processing Record 1 of Set 4 | vaitape
# Processing Record 2 of Set 4 | bosaso
# Processing Record 3 of Set 4 | ballina
# Processing Record 4 of Set 4 | hobart
# Processing Record 5 of Set 4 | zhangye
# Processing Record 6 of Set 4 | ambatofinandrahana
# Processing Record 7 of Set 4 | chuy
# Processing Record 8 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 4 | miastko
# Processing Record 10 of Set 4 | kalmunai
# Processing Record 11 of Set 4 | khatanga
# Processing Record 12 of Set 4 | hervey bay
# Processing Record 13 of Set 4 | roald
# Processing Record 14 of Set 4 | atasu
# Processing Record 15 of Set 4 | saint-raymond
# Processing Record 16 of Set 4 | peniche
# Processing Record 17 of Set 4 | quito
# Processing Record 18 of Set 4 | pochutla
# Processing Record 19 of Set 4 | borger
# Processing Record 20 of Set 4 | nova vicosa
# Processing Record 21 of Set 4 | faanui
# Processing Record 22 of Set 4 | kalaleh
# Processing Record 23 of Set 4 | emerald
# Processing Record 24 of Set 4 | bethel
# Processing Record 25 of Set 4 | maarianhamina
# Processing Record 26 of Set 4 | port hardy
# Processing Record 27 of Set 4 | mubi
# Processing Record 28 of Set 4 | adrar
# Processing Record 29 of Set 4 | hirara
# Processing Record 30 of Set 4 | carnaiba
# Processing Record 31 of Set 4 | namatanai
# Processing Record 32 of Set 4 | tuktoyaktuk
# Processing Record 33 of Set 4 | bathsheba
# Processing Record 34 of Set 4 | dali
# Processing Record 35 of Set 4 | ancud
# Processing Record 36 of Set 4 | tiksi
# Processing Record 37 of Set 4 | saint-pierre
# Processing Record 38 of Set 4 | aleksandrov gay
# Processing Record 39 of Set 4 | drumheller
# Processing Record 40 of Set 4 | purpe
# Processing Record 41 of Set 4 | katherine
# Processing Record 42 of Set 4 | guaruja
# Processing Record 43 of Set 4 | yulara
# Processing Record 44 of Set 4 | mansa
# Processing Record 45 of Set 4 | lieksa
# Processing Record 46 of Set 4 | byron bay
# Processing Record 47 of Set 4 | mount gambier
# Processing Record 48 of Set 4 | mmabatho
# Processing Record 49 of Set 4 | te anau
# Processing Record 50 of Set 4 | vardo
# Processing Record 1 of Set 5 | iqaluit
# Processing Record 2 of Set 5 | matara
# Processing Record 3 of Set 5 | kopavogur
# Processing Record 4 of Set 5 | tabou
# Processing Record 5 of Set 5 | espirito santo do pinhal
# Processing Record 6 of Set 5 | shuangcheng
# Processing Record 7 of Set 5 | leningradskiy
# Processing Record 8 of Set 5 | bow island
# Processing Record 9 of Set 5 | kirakira
# Processing Record 10 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 5 | champerico
# Processing Record 12 of Set 5 | vila velha
# Processing Record 13 of Set 5 | jakoruda
# City not found. Skipping...
# Processing Record 14 of Set 5 | kavaratti
# Processing Record 15 of Set 5 | husavik
# Processing Record 16 of Set 5 | viedma
# Processing Record 17 of Set 5 | wajima
# Processing Record 18 of Set 5 | bacolod
# Processing Record 19 of Set 5 | taber
# Processing Record 20 of Set 5 | copiapo
# Processing Record 21 of Set 5 | cap malheureux
# Processing Record 22 of Set 5 | taoudenni
# Processing Record 23 of Set 5 | kahului
# Processing Record 24 of Set 5 | mahadday weyne
# City not found. Skipping...
# Processing Record 25 of Set 5 | luwingu
# Processing Record 26 of Set 5 | haibowan
# City not found. Skipping...
# Processing Record 27 of Set 5 | dreux
# Processing Record 28 of Set 5 | flinders
# Processing Record 29 of Set 5 | port macquarie
# Processing Record 30 of Set 5 | petrove
# Processing Record 31 of Set 5 | hasaki
# Processing Record 32 of Set 5 | pimentel
# Processing Record 33 of Set 5 | rio gallegos
# Processing Record 34 of Set 5 | hambantota
# Processing Record 35 of Set 5 | marawi
# Processing Record 36 of Set 5 | kemijarvi
# Processing Record 37 of Set 5 | llangefni
# Processing Record 38 of Set 5 | mount isa
# Processing Record 39 of Set 5 | nemuro
# Processing Record 40 of Set 5 | north bend
# Processing Record 41 of Set 5 | nuuk
# Processing Record 42 of Set 5 | natal
# Processing Record 43 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 44 of Set 5 | mudon
# Processing Record 45 of Set 5 | agadez
# Processing Record 46 of Set 5 | kavieng
# Processing Record 47 of Set 5 | port moresby
# Processing Record 48 of Set 5 | tuatapere
# Processing Record 49 of Set 5 | bougouni
# Processing Record 50 of Set 5 | comodoro rivadavia
# Processing Record 1 of Set 6 | nelson bay
# Processing Record 2 of Set 6 | maragogi
# Processing Record 3 of Set 6 | wanning
# Processing Record 4 of Set 6 | verkh-usugli
# Processing Record 5 of Set 6 | mokhsogollokh
# Processing Record 6 of Set 6 | batesville
# Processing Record 7 of Set 6 | junagarh
# Processing Record 8 of Set 6 | troitsko-pechorsk
# Processing Record 9 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 10 of Set 6 | tiznit
# Processing Record 11 of Set 6 | am timan
# Processing Record 12 of Set 6 | filingue
# Processing Record 13 of Set 6 | ngunguru
# Processing Record 14 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 6 | balasheyka
# Processing Record 16 of Set 6 | grindavik
# Processing Record 17 of Set 6 | colares
# Processing Record 18 of Set 6 | skegness
# Processing Record 19 of Set 6 | bodden town
# Processing Record 20 of Set 6 | dalbandin
# Processing Record 21 of Set 6 | otopeni
# Processing Record 22 of Set 6 | warri
# Processing Record 23 of Set 6 | nosy varika
# Processing Record 24 of Set 6 | amarante do maranhao
# Processing Record 25 of Set 6 | rocha
# Processing Record 26 of Set 6 | mendahara
# City not found. Skipping...
# Processing Record 27 of Set 6 | horodyshche
# Processing Record 28 of Set 6 | bilibino
# Processing Record 29 of Set 6 | dorado
# Processing Record 30 of Set 6 | ponta do sol
# Processing Record 31 of Set 6 | katsuura
# Processing Record 32 of Set 6 | fereydun kenar
# Processing Record 33 of Set 6 | kruisfontein
# Processing Record 34 of Set 6 | santa maria
# Processing Record 35 of Set 6 | gizo
# Processing Record 36 of Set 6 | alakurtti
# Processing Record 37 of Set 6 | andenes
# Processing Record 38 of Set 6 | hofn
# Processing Record 39 of Set 6 | kiama
# Processing Record 40 of Set 6 | coihaique
# Processing Record 41 of Set 6 | jutai
# Processing Record 42 of Set 6 | hun
# Processing Record 43 of Set 6 | maua
# Processing Record 44 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 6 | fort nelson
# Processing Record 46 of Set 6 | sedalia
# Processing Record 47 of Set 6 | clinton
# Processing Record 48 of Set 6 | tikrit
# Processing Record 49 of Set 6 | tra vinh
# Processing Record 50 of Set 6 | bograd
# Processing Record 1 of Set 7 | hamilton
# Processing Record 2 of Set 7 | oranjestad
# Processing Record 3 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 7 | vila franca do campo
# Processing Record 5 of Set 7 | celestun
# Processing Record 6 of Set 7 | tamandare
# Processing Record 7 of Set 7 | jacarau
# Processing Record 8 of Set 7 | sal rei
# Processing Record 9 of Set 7 | bagotville
# Processing Record 10 of Set 7 | pasni
# Processing Record 11 of Set 7 | iralaya
# Processing Record 12 of Set 7 | taman
# Processing Record 13 of Set 7 | okha
# Processing Record 14 of Set 7 | sibolga
# Processing Record 15 of Set 7 | beihai
# Processing Record 16 of Set 7 | alcaniz
# Processing Record 17 of Set 7 | beringovskiy
# Processing Record 18 of Set 7 | ahipara
# Processing Record 19 of Set 7 | sindor
# Processing Record 20 of Set 7 | aleysk
# Processing Record 21 of Set 7 | bam
# Processing Record 22 of Set 7 | caravelas
# Processing Record 23 of Set 7 | terra santa
# Processing Record 24 of Set 7 | saldanha
# Processing Record 25 of Set 7 | lata
# Processing Record 26 of Set 7 | codrington
# Processing Record 27 of Set 7 | raga
# Processing Record 28 of Set 7 | nyurba
# Processing Record 29 of Set 7 | kidal
# Processing Record 30 of Set 7 | carauari
# Processing Record 31 of Set 7 | castanos
# Processing Record 32 of Set 7 | nome
# Processing Record 33 of Set 7 | dubai
# Processing Record 34 of Set 7 | imbituba
# Processing Record 35 of Set 7 | dingle
# Processing Record 36 of Set 7 | kokopo
# Processing Record 37 of Set 7 | walvis bay
# Processing Record 38 of Set 7 | aksarka
# Processing Record 39 of Set 7 | talnakh
# Processing Record 40 of Set 7 | hualmay
# Processing Record 41 of Set 7 | genhe
# Processing Record 42 of Set 7 | sao filipe
# Processing Record 43 of Set 7 | nadvoitsy
# Processing Record 44 of Set 7 | anadyr
# Processing Record 45 of Set 7 | oussouye
# Processing Record 46 of Set 7 | rovaniemi
# Processing Record 47 of Set 7 | hingorja
# Processing Record 48 of Set 7 | east london
# Processing Record 49 of Set 7 | wageningen
# Processing Record 50 of Set 7 | pekan
# Processing Record 1 of Set 8 | fairbanks
# Processing Record 2 of Set 8 | vanderhoof
# Processing Record 3 of Set 8 | shubarshi
# Processing Record 4 of Set 8 | fortuna
# Processing Record 5 of Set 8 | poum
# Processing Record 6 of Set 8 | lewistown
# Processing Record 7 of Set 8 | gamba
# Processing Record 8 of Set 8 | cabo san lucas
# Processing Record 9 of Set 8 | one hundred mile house
# City not found. Skipping...
# Processing Record 10 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 8 | ilo
# Processing Record 12 of Set 8 | spencer
# Processing Record 13 of Set 8 | vao
# Processing Record 14 of Set 8 | kazerun
# Processing Record 15 of Set 8 | whitianga
# Processing Record 16 of Set 8 | nova olinda do norte
# Processing Record 17 of Set 8 | kunya
# Processing Record 18 of Set 8 | sawtell
# Processing Record 19 of Set 8 | utiel
# Processing Record 20 of Set 8 | svetlyy
# Processing Record 21 of Set 8 | karpathos
# Processing Record 22 of Set 8 | hovd
# Processing Record 23 of Set 8 | fort saint james
# Processing Record 24 of Set 8 | umm lajj
# Processing Record 25 of Set 8 | general roca
# Processing Record 26 of Set 8 | muriwai beach
# Processing Record 27 of Set 8 | cah ab
# City not found. Skipping...
# Processing Record 28 of Set 8 | jomalig
# City not found. Skipping...
# Processing Record 29 of Set 8 | omboue
# Processing Record 30 of Set 8 | beyneu
# Processing Record 31 of Set 8 | anzio
# Processing Record 32 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 33 of Set 8 | kaeo
# Processing Record 34 of Set 8 | ozark
# Processing Record 35 of Set 8 | palembang
# Processing Record 36 of Set 8 | balotra
# Processing Record 37 of Set 8 | mardin
# Processing Record 38 of Set 8 | labuhan
# Processing Record 39 of Set 8 | coutances
# Processing Record 40 of Set 8 | khlung
# Processing Record 41 of Set 8 | moerai
# Processing Record 42 of Set 8 | envira
# Processing Record 43 of Set 8 | taunggyi
# Processing Record 44 of Set 8 | norman wells
# Processing Record 45 of Set 8 | nibong tebal
# Processing Record 46 of Set 8 | saint-francois
# Processing Record 47 of Set 8 | saint george
# Processing Record 48 of Set 8 | pisco
# Processing Record 49 of Set 8 | szolnok
# Processing Record 50 of Set 8 | port arthur
# Processing Record 1 of Set 9 | port lincoln
# Processing Record 2 of Set 9 | atar
# Processing Record 3 of Set 9 | cao bang
# Processing Record 4 of Set 9 | amalapuram
# Processing Record 5 of Set 9 | lalibela
# Processing Record 6 of Set 9 | puerto madero
# Processing Record 7 of Set 9 | paveh
# Processing Record 8 of Set 9 | corner brook
# Processing Record 9 of Set 9 | kumba
# Processing Record 10 of Set 9 | shenxian
# Processing Record 11 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 9 | pathein
# Processing Record 13 of Set 9 | ocos
# Processing Record 14 of Set 9 | zalantun
# Processing Record 15 of Set 9 | yining
# Processing Record 16 of Set 9 | faya
# Processing Record 17 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 18 of Set 9 | nurota
# Processing Record 19 of Set 9 | linqiong
# Processing Record 20 of Set 9 | xam nua
# Processing Record 21 of Set 9 | maceio
# Processing Record 22 of Set 9 | richards bay
# Processing Record 23 of Set 9 | suileng
# Processing Record 24 of Set 9 | geraldton
# Processing Record 25 of Set 9 | bud
# Processing Record 26 of Set 9 | san ignacio
# Processing Record 27 of Set 9 | ngama
# Processing Record 28 of Set 9 | taupo
# Processing Record 29 of Set 9 | tafo
# Processing Record 30 of Set 9 | anchorage
# Processing Record 31 of Set 9 | waitara
# Processing Record 32 of Set 9 | tsumeb
# Processing Record 33 of Set 9 | coos bay
# Processing Record 34 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 35 of Set 9 | sarh
# Processing Record 36 of Set 9 | krasnoarmeysk
# Processing Record 37 of Set 9 | kutum
# Processing Record 38 of Set 9 | pacific grove
# Processing Record 39 of Set 9 | seoul
# Processing Record 40 of Set 9 | broken hill
# Processing Record 41 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 42 of Set 9 | fort william
# Processing Record 43 of Set 9 | perth
# Processing Record 44 of Set 9 | tautira
# Processing Record 45 of Set 9 | steenbergen
# Processing Record 46 of Set 9 | derzhavinsk
# Processing Record 47 of Set 9 | arlit
# Processing Record 48 of Set 9 | brae
# Processing Record 49 of Set 9 | havre-saint-pierre
# Processing Record 50 of Set 9 | shakhunya
# Processing Record 1 of Set 10 | sayansk
# Processing Record 2 of Set 10 | ismailia
# Processing Record 3 of Set 10 | ishinomaki
# Processing Record 4 of Set 10 | cosautlan
# Processing Record 5 of Set 10 | tessalit
# Processing Record 6 of Set 10 | turayf
# Processing Record 7 of Set 10 | aykhal
# Processing Record 8 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 10 | pangai
# Processing Record 10 of Set 10 | astoria
# Processing Record 11 of Set 10 | mitsamiouli
# Processing Record 12 of Set 10 | aras
# Processing Record 13 of Set 10 | canguaretama
# Processing Record 14 of Set 10 | eureka
# Processing Record 15 of Set 10 | mersing
# Processing Record 16 of Set 10 | wahran
# City not found. Skipping...
# Processing Record 17 of Set 10 | acarau
# Processing Record 18 of Set 10 | mugur-aksy
# Processing Record 19 of Set 10 | lamballe
# Processing Record 20 of Set 10 | ozgon
# City not found. Skipping...
# Processing Record 21 of Set 10 | cascais
# Processing Record 22 of Set 10 | port-gentil
# Processing Record 23 of Set 10 | port blair
# Processing Record 24 of Set 10 | vysokogornyy
# Processing Record 25 of Set 10 | toora-khem
# Processing Record 26 of Set 10 | kurilsk
# Processing Record 27 of Set 10 | los llanos de aridane
# Processing Record 28 of Set 10 | asau
# Processing Record 29 of Set 10 | conde
# Processing Record 30 of Set 10 | saint-georges
# Processing Record 31 of Set 10 | falmouth
# Processing Record 32 of Set 10 | kinlochleven
# Processing Record 33 of Set 10 | findhorn
# Processing Record 34 of Set 10 | paungde
# Processing Record 35 of Set 10 | touros
# Processing Record 36 of Set 10 | korla
# Processing Record 37 of Set 10 | baltay
# Processing Record 38 of Set 10 | seryshevo
# Processing Record 39 of Set 10 | palmer
# Processing Record 40 of Set 10 | vanimo
# Processing Record 41 of Set 10 | madras
# Processing Record 42 of Set 10 | tanout
# Processing Record 43 of Set 10 | polyarnyy
# Processing Record 44 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 10 | blackfoot
# Processing Record 46 of Set 10 | rio grande
# Processing Record 47 of Set 10 | caohe
# Processing Record 48 of Set 10 | pombia
# Processing Record 49 of Set 10 | polunochnoye
# Processing Record 50 of Set 10 | sabang
# Processing Record 1 of Set 11 | kracheh
# City not found. Skipping...
# Processing Record 2 of Set 11 | rawson
# Processing Record 3 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 11 | merrill
# Processing Record 5 of Set 11 | sao miguel do araguaia
# Processing Record 6 of Set 11 | saint-augustin
# Processing Record 7 of Set 11 | sladkovo
# Processing Record 8 of Set 11 | mangan
# Processing Record 9 of Set 11 | nikolskoye
# Processing Record 10 of Set 11 | les cayes
# Processing Record 11 of Set 11 | kautokeino
# Processing Record 12 of Set 11 | hengshui
# Processing Record 13 of Set 11 | half moon bay
# Processing Record 14 of Set 11 | lehigh acres
# Processing Record 15 of Set 11 | olafsvik
# Processing Record 16 of Set 11 | boulsa
# Processing Record 17 of Set 11 | luganville
# Processing Record 18 of Set 11 | mission bend
# Processing Record 19 of Set 11 | banda aceh
# Processing Record 20 of Set 11 | bima
# Processing Record 21 of Set 11 | lokachi
# Processing Record 22 of Set 11 | mao
# Processing Record 23 of Set 11 | ventspils
# Processing Record 24 of Set 11 | ilulissat
# Processing Record 25 of Set 11 | juneau
# Processing Record 26 of Set 11 | katobu
# Processing Record 27 of Set 11 | tanete
# Processing Record 28 of Set 11 | wahpeton
# Processing Record 29 of Set 11 | cabedelo
# Processing Record 30 of Set 11 | mattoon
# Processing Record 31 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 32 of Set 11 | kimberley
# Processing Record 33 of Set 11 | harlingen
# Processing Record 34 of Set 11 | siyabuswa
# Processing Record 35 of Set 11 | maldonado
# Processing Record 36 of Set 11 | wiang sa
# Processing Record 37 of Set 11 | sestu
# Processing Record 38 of Set 11 | guder
# Processing Record 39 of Set 11 | markt schwaben
# Processing Record 40 of Set 11 | luanda
# Processing Record 41 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 42 of Set 11 | lebu
# Processing Record 43 of Set 11 | san patricio
# Processing Record 44 of Set 11 | peterhead
# Processing Record 45 of Set 11 | uruacu
# Processing Record 46 of Set 11 | sidmouth
# Processing Record 47 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 11 | pemba
# Processing Record 49 of Set 11 | abalak
# Processing Record 50 of Set 11 | marystown
# Processing Record 1 of Set 12 | manta
# Processing Record 2 of Set 12 | road town
# Processing Record 3 of Set 12 | lavrentiya
# Processing Record 4 of Set 12 | beirut
# Processing Record 5 of Set 12 | ternate
# Processing Record 6 of Set 12 | bissau
# Processing Record 7 of Set 12 | hayvoron
# Processing Record 8 of Set 12 | port hedland
# Processing Record 9 of Set 12 | haines junction
# Processing Record 10 of Set 12 | machali
# Processing Record 11 of Set 12 | kovur
# Processing Record 12 of Set 12 | eskisehir
# Processing Record 13 of Set 12 | sola
# Processing Record 14 of Set 12 | vostok
# Processing Record 15 of Set 12 | san andres
# Processing Record 16 of Set 12 | zhicheng
# Processing Record 17 of Set 12 | eldikan
# City not found. Skipping...
# Processing Record 18 of Set 12 | tshela
# Processing Record 19 of Set 12 | sao jose da coroa grande
# Processing Record 20 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 21 of Set 12 | the valley
# Processing Record 22 of Set 12 | dogondoutchi
# Processing Record 23 of Set 12 | ladario
# Processing Record 24 of Set 12 | samoded
# Processing Record 25 of Set 12 | yenagoa
# Processing Record 26 of Set 12 | immokalee
# Processing Record 27 of Set 12 | santa cruz
# Processing Record 28 of Set 12 | campobasso
# Processing Record 29 of Set 12 | altay
# Processing Record 30 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 31 of Set 12 | constitucion
# Processing Record 32 of Set 12 | midland
# Processing Record 33 of Set 12 | sretensk
# Processing Record 34 of Set 12 | bilhaur
# Processing Record 35 of Set 12 | mocuba
# Processing Record 36 of Set 12 | igarka
# Processing Record 37 of Set 12 | staryy nadym
# Processing Record 38 of Set 12 | sekoma
# Processing Record 39 of Set 12 | kushiro
# Processing Record 40 of Set 12 | jadu
# Processing Record 41 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 12 | gimli
# Processing Record 43 of Set 12 | kamiiso
# Processing Record 44 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 45 of Set 12 | anju
# Processing Record 46 of Set 12 | carnduff
# Processing Record 47 of Set 12 | sakakah
# Processing Record 48 of Set 12 | dhidhdhoo
# Processing Record 49 of Set 12 | varadero
# Processing Record 50 of Set 12 | hagere hiywet
# Processing Record 1 of Set 13 | murud
# Processing Record 2 of Set 13 | alice springs
# Processing Record 3 of Set 13 | cherusti
# Processing Record 4 of Set 13 | kayankulam
# Processing Record 5 of Set 13 | unai
# Processing Record 6 of Set 13 | seymchan
# Processing Record 7 of Set 13 | mana
# Processing Record 8 of Set 13 | cururupu
# Processing Record 9 of Set 13 | maple creek
# Processing Record 10 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 11 of Set 13 | marsa matruh
# Processing Record 12 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 13 of Set 13 | dakoro
# Processing Record 14 of Set 13 | anaimalai
# Processing Record 15 of Set 13 | kapit
# Processing Record 16 of Set 13 | kabare
# Processing Record 17 of Set 13 | nohar
# Processing Record 18 of Set 13 | pedasi
# Processing Record 19 of Set 13 | plettenberg bay
# Processing Record 20 of Set 13 | shimoda
# Processing Record 21 of Set 13 | portland
# Processing Record 22 of Set 13 | wulanhaote
# City not found. Skipping...
# Processing Record 23 of Set 13 | mamallapuram
# Processing Record 24 of Set 13 | awash
# Processing Record 25 of Set 13 | iskateley
# Processing Record 26 of Set 13 | thohoyandou
# Processing Record 27 of Set 13 | bhanpuri
# Processing Record 28 of Set 13 | gat
# Processing Record 29 of Set 13 | butte
# Processing Record 30 of Set 13 | luba
# Processing Record 31 of Set 13 | mitchell
# Processing Record 32 of Set 13 | funadhoo
# Processing Record 33 of Set 13 | salina
# Processing Record 34 of Set 13 | palu
# Processing Record 35 of Set 13 | edd
# Processing Record 36 of Set 13 | defiance
# Processing Record 37 of Set 13 | grand gaube
# Processing Record 38 of Set 13 | gayny
# Processing Record 39 of Set 13 | shenjiamen
# Processing Record 40 of Set 13 | baruun-urt
# Processing Record 41 of Set 13 | rudnogorsk
# Processing Record 42 of Set 13 | paternion
# Processing Record 43 of Set 13 | hohhot
# Processing Record 44 of Set 13 | garissa
# Processing Record 45 of Set 13 | palana
# Processing Record 46 of Set 13 | loding
# Processing Record 47 of Set 13 | huarmey
# Processing Record 48 of Set 13 | saint-leu
# Processing Record 49 of Set 13 | puerto escondido
# Processing Record 50 of Set 13 | daytona beach
# Processing Record 1 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 14 | guerrero negro
# Processing Record 3 of Set 14 | petauke
# Processing Record 4 of Set 14 | goderich
# Processing Record 5 of Set 14 | quang ngai
# Processing Record 6 of Set 14 | avera
# Processing Record 7 of Set 14 | chardara
# Processing Record 8 of Set 14 | ganzhou
# Processing Record 9 of Set 14 | bokoro
# Processing Record 10 of Set 14 | northam
# Processing Record 11 of Set 14 | okoneshnikovo
# Processing Record 12 of Set 14 | tigre
# Processing Record 13 of Set 14 | morris
# Processing Record 14 of Set 14 | chifeng
# Processing Record 15 of Set 14 | sibu
# Processing Record 16 of Set 14 | mpanda
# Processing Record 17 of Set 14 | sinnamary
# Processing Record 18 of Set 14 | new baltimore
# Processing Record 19 of Set 14 | surab
# Processing Record 20 of Set 14 | cairns
# Processing Record 21 of Set 14 | aqtobe
# Processing Record 22 of Set 14 | sarlat-la-caneda
# Processing Record 23 of Set 14 | inongo
# Processing Record 24 of Set 14 | kriel
# Processing Record 25 of Set 14 | horki
# Processing Record 26 of Set 14 | basco
# Processing Record 27 of Set 14 | sioux lookout
# Processing Record 28 of Set 14 | oriximina
# Processing Record 29 of Set 14 | mayo
# Processing Record 30 of Set 14 | brazzaville
# Processing Record 31 of Set 14 | acari
# Processing Record 32 of Set 14 | aklavik
# Processing Record 33 of Set 14 | manokwari
# Processing Record 34 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 35 of Set 14 | panaba
# Processing Record 36 of Set 14 | mehamn
# Processing Record 37 of Set 14 | makakilo city
# Processing Record 38 of Set 14 | bereda
# Processing Record 39 of Set 14 | waingapu
# Processing Record 40 of Set 14 | opotiki
# Processing Record 41 of Set 14 | hamada
# Processing Record 42 of Set 14 | muros
# Processing Record 43 of Set 14 | koslan
# Processing Record 44 of Set 14 | gao
# Processing Record 45 of Set 14 | borgarnes
# Processing Record 46 of Set 14 | wamba
# Processing Record 47 of Set 14 | westpunt
# City not found. Skipping...
# Processing Record 48 of Set 14 | mildura
# Processing Record 49 of Set 14 | erenhot
# Processing Record 50 of Set 14 | puerto madryn
# Processing Record 1 of Set 15 | west bay
# Processing Record 2 of Set 15 | jacksonville
# Processing Record 3 of Set 15 | sovetskiy
# Processing Record 4 of Set 15 | bay roberts
# Processing Record 5 of Set 15 | orlik
# Processing Record 6 of Set 15 | riyadh
# Processing Record 7 of Set 15 | sorong
# Processing Record 8 of Set 15 | mwinilunga
# Processing Record 9 of Set 15 | west wendover
# Processing Record 10 of Set 15 | vila
# Processing Record 11 of Set 15 | dimitrie cantemir
# Processing Record 12 of Set 15 | montevideo
# Processing Record 13 of Set 15 | yakeshi
# Processing Record 14 of Set 15 | colac
# Processing Record 15 of Set 15 | nikolsk
# Processing Record 16 of Set 15 | korablino
# Processing Record 17 of Set 15 | spornoye
# Processing Record 18 of Set 15 | jeremoabo
# Processing Record 19 of Set 15 | sorland
# Processing Record 20 of Set 15 | mindelo
# Processing Record 21 of Set 15 | hohoe
# Processing Record 22 of Set 15 | araouane
# Processing Record 23 of Set 15 | ilhabela
# Processing Record 24 of Set 15 | kenai
# Processing Record 25 of Set 15 | glenwood springs
# Processing Record 26 of Set 15 | swan river
# Processing Record 27 of Set 15 | manikchhari
# City not found. Skipping...
# Processing Record 28 of Set 15 | trzebiatow
# Processing Record 29 of Set 15 | santiago de cao
# Processing Record 30 of Set 15 | laguna
# Processing Record 31 of Set 15 | mountain home
# Processing Record 32 of Set 15 | nishihara
# Processing Record 33 of Set 15 | jorochito
# Processing Record 34 of Set 15 | aguimes
# Processing Record 35 of Set 15 | tigil
# Processing Record 36 of Set 15 | manggar
# Processing Record 37 of Set 15 | college
# Processing Record 38 of Set 15 | bowen
# Processing Record 39 of Set 15 | gold coast
# Processing Record 40 of Set 15 | buqayq
# City not found. Skipping...
# Processing Record 41 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 42 of Set 15 | goksun
# Processing Record 43 of Set 15 | bindura
# Processing Record 44 of Set 15 | porto novo
# Processing Record 45 of Set 15 | camacha
# Processing Record 46 of Set 15 | prince rupert
# Processing Record 47 of Set 15 | imelda
# Processing Record 48 of Set 15 | yinchuan
# Processing Record 49 of Set 15 | qasigiannguit
# Processing Record 50 of Set 15 | bilma
# Processing Record 1 of Set 16 | falealupo
# City not found. Skipping...
# Processing Record 2 of Set 16 | port-cartier
# Processing Record 3 of Set 16 | abha
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Saint-Philippe -21.3585   55.7679     78.39        82          46
# 1          Kodiak  57.7900 -152.4072     26.11        68           0
# 2       Busselton -33.6500  115.3333     63.09        64          90
# 3         Cayenne   4.9333  -52.3333     78.84        88          75
# 4       Upernavik  72.7868  -56.1549     -3.71        87         100
# 5        Khandyga  62.6667  135.6000    -39.64       100          77
# 6         Mirabad  30.4362   61.8383     52.72        45          20
# 7          Narsaq  60.9167  -46.0500     23.22        72         100
# 8         Orvieto  42.7195   12.1116     46.29        84           0
# 9          Dalmau  26.0667   81.0333     53.01        64           0
#
#    Wind Speed Current Description Country                 Date
# 0       11.36    scattered clouds      RE  2022-01-30 21:41:34
# 1       12.66           clear sky      US  2022-01-30 21:40:13
# 2       18.16     overcast clouds      AU  2022-01-30 21:40:14
# 3        1.99       broken clouds      GF  2022-01-30 21:41:35
# 4        6.26     overcast clouds      GL  2022-01-30 21:41:30
# 5        1.28       broken clouds      RU  2022-01-30 21:41:35
# 6        7.11          few clouds      AF  2022-01-30 21:41:36
# 7       17.52                snow      GL  2022-01-30 21:37:12
# 8        0.96           clear sky      IT  2022-01-30 21:41:36
# 9        1.10           clear sky      IN  2022-01-30 21:41:36

# %%
new_column_order = ["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0  Saint-Philippe      RE  2022-01-30 21:41:34 -21.3585   55.7679     78.39
# 1          Kodiak      US  2022-01-30 21:40:13  57.7900 -152.4072     26.11
# 2       Busselton      AU  2022-01-30 21:40:14 -33.6500  115.3333     63.09
# 3         Cayenne      GF  2022-01-30 21:41:35   4.9333  -52.3333     78.84
# 4       Upernavik      GL  2022-01-30 21:41:30  72.7868  -56.1549     -3.71
# 5        Khandyga      RU  2022-01-30 21:41:35  62.6667  135.6000    -39.64
# 6         Mirabad      AF  2022-01-30 21:41:36  30.4362   61.8383     52.72
# 7          Narsaq      GL  2022-01-30 21:37:12  60.9167  -46.0500     23.22
# 8         Orvieto      IT  2022-01-30 21:41:36  42.7195   12.1116     46.29
# 9          Dalmau      IN  2022-01-30 21:41:36  26.0667   81.0333     53.01
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        82          46       11.36    scattered clouds
# 1        68           0       12.66           clear sky
# 2        64          90       18.16     overcast clouds
# 3        88          75        1.99       broken clouds
# 4        87         100        6.26     overcast clouds
# 5       100          77        1.28       broken clouds
# 6        45          20        7.11          few clouds
# 7        72         100       17.52                snow
# 8        84           0        0.96           clear sky
# 9        64           0        1.10           clear sky

# %%
# Export the City_Data into a CSV.
city_data_df.to_csv("WeatherPy_Database.csv", index_label="City_ID")
